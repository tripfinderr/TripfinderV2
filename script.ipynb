-- %% [markdown]
-- # [TRIP_FINDER]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [TRIP_FINDER]    Script Date: 14.06.2021 01:49:53 ******/
CREATE DATABASE [TRIP_FINDER]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'TRIP_FINDER', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\TRIP_FINDER.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'TRIP_FINDER_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\TRIP_FINDER_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [TRIP_FINDER] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [TRIP_FINDER].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [TRIP_FINDER] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET ARITHABORT OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [TRIP_FINDER] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [TRIP_FINDER] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET  DISABLE_BROKER 
GO
ALTER DATABASE [TRIP_FINDER] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [TRIP_FINDER] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET RECOVERY FULL 
GO
ALTER DATABASE [TRIP_FINDER] SET  MULTI_USER 
GO
ALTER DATABASE [TRIP_FINDER] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [TRIP_FINDER] SET DB_CHAINING OFF 
GO
ALTER DATABASE [TRIP_FINDER] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [TRIP_FINDER] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [TRIP_FINDER] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [TRIP_FINDER] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'TRIP_FINDER', N'ON'
GO
ALTER DATABASE [TRIP_FINDER] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [NT AUTHORITY\SYSTEM]

-- %%
USE [TRIP_FINDER]
GO

-- %%
/****** Object:  User [NT AUTHORITY\SYSTEM]    Script Date: 14.06.2021 01:49:53 ******/
CREATE USER [NT AUTHORITY\SYSTEM] FOR LOGIN [NT AUTHORITY\SYSTEM] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %%
ALTER ROLE [db_owner] ADD MEMBER [NT AUTHORITY\SYSTEM]
GO

-- %% [markdown]
-- # [dbo].[Favlar]

-- %%
/****** Object:  Table [dbo].[Favlar]    Script Date: 14.06.2021 01:49:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Favlar](
	[UserNickName] [varchar](200) NULL,
	[MekanIsimleri] [varchar](200) NULL,
	[Favori] [varchar](200) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GidilenMekanlarByUsers]

-- %%
/****** Object:  Table [dbo].[GidilenMekanlarByUsers]    Script Date: 14.06.2021 01:49:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GidilenMekanlarByUsers](
	[UserNickName] [varchar](200) NULL,
	[GidilenMekan] [varchar](200) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HavaDurumu]

-- %%
/****** Object:  Table [dbo].[HavaDurumu]    Script Date: 14.06.2021 01:49:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HavaDurumu](
	[Sehir] [varchar](50) NULL,
	[Ilce] [varchar](50) NULL,
	[CDerece] [bigint] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Notlar]

-- %%
/****** Object:  Table [dbo].[Notlar]    Script Date: 14.06.2021 01:49:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Notlar](
	[Notlar] [varchar](8000) NULL,
	[UserNickName] [varchar](200) NULL,
	[NotBasligi] [varchar](500) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SehirDurumlari]

-- %%
/****** Object:  Table [dbo].[SehirDurumlari]    Script Date: 14.06.2021 01:49:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SehirDurumlari](
	[Sehirler] [varchar](200) NULL,
	[ServisDurumu] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Turlar]

-- %%
/****** Object:  Table [dbo].[Turlar]    Script Date: 14.06.2021 01:49:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Turlar](
	[UserId] [int] NULL,
	[Turİsmi] [varchar](200) NULL,
	[MekanIsimleri] [varchar](200) NULL,
	[Kordinatlar] [varchar](200) NULL,
	[MekanAciklamalari] [varchar](200) NULL,
	[MekanFotoURL] [varchar](5000) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserInformations]

-- %%
/****** Object:  Table [dbo].[UserInformations]    Script Date: 14.06.2021 01:49:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserInformations](
	[UserId] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](1000) NULL,
	[UserSurname] [varchar](1000) NULL,
	[UserMailAdress] [varchar](1000) NULL,
	[UserNickName] [varchar](1000) NULL,
	[UserPassword] [varchar](1000) NULL,
	[UserAgainPassword] [varchar](1000) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserInformations1]

-- %%
/****** Object:  Table [dbo].[UserInformations1]    Script Date: 14.06.2021 01:49:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserInformations1](
	[UserId] [bigint] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](1000) NULL,
	[UserSurname] [varchar](1000) NULL,
	[UserMailAdress] [varchar](1000) NULL,
	[UserNickName] [varchar](1000) NULL,
	[UserPassword] [varchar](1000) NULL,
	[UserAgainPassword] [varchar](1000) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Yorumlar]

-- %%
/****** Object:  Table [dbo].[Yorumlar]    Script Date: 14.06.2021 01:49:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Yorumlar](
	[UserNickName] [varchar](200) NULL,
	[TurIsmi] [varchar](200) NULL,
	[MekanIsimleri] [varchar](200) NULL,
	[MekanYorumu] [varchar](1000) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [TRIP_FINDER]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [TRIP_FINDER] SET  READ_WRITE 
GO
